# %% [markdown]
# # Import Data

# %%
import cv2
import os
import numpy as np
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
import tensorflow as tf

# %% [markdown]
# Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

origin_path = '/content/drive/My Drive/Colab Notebooks/Metamaterials AI/Preprocessed_Images/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Functions

# %% [markdown]
# Resize Images

# %%
# Function to resize images while keeping red and yellow regions
def resize_retain_colors(image):
  # Convert the image to the HSV color space
  hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

  # Define broader bounds for yellow color in HSV
  lower_yellow = np.array([10, 50, 50])
  upper_yellow = np.array([40, 255, 255])

  # Define broader bounds for red color in HSV
  lower_red1 = np.array([0, 50, 50])
  upper_red1 = np.array([10, 255, 255])
  lower_red2 = np.array([160, 50, 50])
  upper_red2 = np.array([180, 255, 255])

  # Create masks for yellow and red colors
  yellow_mask = cv2.inRange(hsv_image, lower_yellow, upper_yellow)
  red_mask1 = cv2.inRange(hsv_image, lower_red1, upper_red1)
  red_mask2 = cv2.inRange(hsv_image, lower_red2, upper_red2)
  red_mask = red_mask1 + red_mask2

  # Combine red and yellow masks
  mask_combined = cv2.bitwise_or(red_mask, yellow_mask)

  # Extract red and yellow regions from the original image
  regions_of_interest = cv2.bitwise_and(image, image, mask=mask_combined)

  # Resize the regions of interest to the target size
  resized_regions = cv2.resize(regions_of_interest, target_size, interpolation=cv2.INTER_CUBIC)

  return resized_regions

# %% [markdown]
# Subplots

# %%
def subplots(image1, image2, suptitle, subplot1_title, subplot2_title):
    # Create subplots
    plt.suptitle(suptitle)

    # Adjust the top margin to reduce the gap
    plt.subplots_adjust(top=1.2)

    plt.subplot(1, 2, 1)
    plt.imshow(cv2.cvtColor(image1, cv2.COLOR_BGR2RGB))
    plt.title(subplot1_title)

    plt.subplot(1, 2, 2)
    plt.imshow(cv2.cvtColor(image2, cv2.COLOR_BGR2RGB))
    plt.title(subplot2_title)

    # Show the plot
    plt.show()

# %% [markdown]
# # Conversion to Numpy Arrays

# %% [markdown]
# Good Images

# %%
image = cv2.imread(origin_path + 'Good Image/augmented_0.jpg')
image_array = np.array(image)
print(image_array[250][250])
print("Shape of the image arrayay:", image_array.shape)
# Out:
# [214 254 252]
# Shape of the image arrayay: (525, 700, 3)

# %%
folder_path = origin_path + 'Good Image/'

# Get the list of all files in the folder
image_files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
images = []
for file_name in image_files:
  # Construct the full path to the image file
  image_path = os.path.join(folder_path, file_name)
  images.append(cv2.imread(image_path))

# %%
images_array = np.array(images)
print(images_array.shape)
print(images_array.shape[0])
# Out:
# (416, 525, 700, 3)
# 416

# %%
# Create an array of labels with a shape matching the number of images
y = np.ones(images_array.shape[0], dtype=int)
print(y.shape)
# Out:
# (416,)

# %% [markdown]
# Bad Images

# %%
folder_path = origin_path + 'Bad Image/'

# Get the list of all files in the folder
image_files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
count = 0
for file_name in image_files:
  # Construct the full path to the image file
  count = count + 1
  image_path = os.path.join(folder_path, file_name)
  images.append(cv2.imread(image_path))

# %%
# Create an array of labels with a shape matching the number of images
y = np.append(y, np.zeros(count, dtype=int))

# %%
images_array = np.array(images)
print(images_array.shape)
y = y.reshape(y.shape[0], 1)
print(y.shape)
# Out:
# (835, 525, 700, 3)
# (835, 1)

# %%
# Use numpy.unique with return_counts=True
unique_values, counts = np.unique(y, return_counts=True)

# Combine unique values and their counts
value_counts = np.column_stack((unique_values, counts))

print(value_counts)
# Out:
# [[  0 419]
#  [  1 416]]

# %%
print(y[0])
print(y[415])
print(y[416])
print(y[834])
# Out:
# [1]
# [1]
# [0]
# [0]

# %% [markdown]
# # Preprocessing Steps

# %% [markdown]
# Reshape

# %%
target_size = (224, 224)

# Apply the resize_retain_colors function to each image in images_array
resized_retained_colors_images = [resize_retain_colors(image) for image in images_array]

# Convert the list of resized and retained colors images to a NumPy array
resized_retained_colors_array = np.array(resized_retained_colors_images)

# Display the shape of the original and resized_retained_colors arrays
print("Original images_array shape:", images_array.shape)
print("Resized and Retained Colors images_array shape:", resized_retained_colors_array.shape)
# Out:
# Original images_array shape: (835, 525, 700, 3)
# Resized and Retained Colors images_array shape: (835, 224, 224, 3)

# %%
img_no = 50
subplots(image1=images_array[img_no], image2=resized_retained_colors_array[img_no], suptitle='Good Image Example', subplot1_title='Original Image', subplot2_title='Modified Image')

# %%
img_no = 516
subplots(image1=images_array[img_no], image2=resized_retained_colors_array[img_no], suptitle='Bad Image Example', subplot1_title='Original Image', subplot2_title='Modified Image')

# %% [markdown]
# Normalization

# %%
normalized_images = []
resized_images_array = resized_retained_colors_array
for image in resized_images_array:
    normalized_image = image / 255.0
    normalized_images.append(normalized_image)

# Convert the list of normalized images to a NumPy array
normalized_images_array = np.array(normalized_images)

# Display the shape of the resized and normalized arrays
print("Resized images_array shape:", resized_images_array.shape)
print("Normalized images_array shape:", normalized_images_array.shape)
# Out:
# Resized images_array shape: (835, 224, 224, 3)
# Normalized images_array shape: (835, 224, 224, 3)

# %%
px = 100
print(resized_images_array[img_no][px][px])
print(normalized_images_array[img_no][px][px])
# Out:
# [0 0 0]
# [0. 0. 0.]

# %%
x = np.array(normalized_images_array)
print(x.shape)
# Out:
# (835, 224, 224, 3)

# %% [markdown]
# Train-Test Splitting

# %%
bad_no = int(count)
good_no = int(x.shape[0] - count)
print('Good Images', good_no)
print('Bad Images', bad_no)
# Out:
# Good Images 416
# Bad Images 419

# %%
percentage = 80
train_good = int(good_no * percentage / 100)
test_good = int(good_no * (100 - percentage) / 100)
train_bad = int(bad_no * percentage / 100)
test_bad = int(bad_no * (100 - percentage) / 100)

print('Training Good', train_good)
print('Testing Good', test_good)
print('Training Bad', train_bad)
print('Testing Bad', test_bad)
# Out:
# Training Good 332
# Testing Good 83
# Training Bad 335
# Testing Bad 83

# %%
X_train_good = x[:train_good + 1]
Y_train_good = y[:train_good + 1]

X_test_good = x[train_good + 1: train_good + test_good + 1]
Y_test_good = y[train_good + 1: train_good + test_good + 1]

print(len(X_train_good), len(X_test_good), len(Y_train_good), len(Y_test_good))
# Out:
# 333 83 333 83

# %%
print(Y_train_good[0])
print(Y_test_good[0])
print(Y_train_good[-1])
print(Y_test_good[-1])
# Out:
# [1]
# [1]
# [1]
# [1]

# %%
X_train_bad = x[train_good + test_good + 1: train_good + test_good + train_bad + 1]
Y_train_bad = y[train_good + test_good + 1: train_good + test_good + train_bad + 1]


X_test_bad = x[train_good + test_good + train_bad + 1: ]
Y_test_bad = y[train_good + test_good + train_bad + 1: ]

print(len(X_train_bad), len(X_test_bad), len(Y_train_bad), len(Y_test_bad))
# Out:
# 335 84 335 84

# %%
print(Y_train_bad[0])
print(Y_test_bad[0])
print(Y_train_bad[-1])
print(Y_test_bad[-1])
# Out:
# [0]
# [0]
# [0]
# [0]

# %%
X_train = np.concatenate((X_train_good, X_train_bad), axis = 0)
Y_train = np.concatenate((Y_train_good, Y_train_bad), axis = 0)

X_test = np.concatenate((X_test_good, X_test_bad), axis = 0)
Y_test = np.concatenate((Y_test_good, Y_test_bad), axis = 0)

print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (668, 224, 224, 3) (668, 1)
# (167, 224, 224, 3) (167, 1)

# %%
print(Y_train[0])
print(Y_train[331])
print(Y_train[332])
print(Y_train[333])
print(Y_train[334])
print(Y_train[-1])
# Out:
# [1]
# [1]
# [1]
# [0]
# [0]
# [0]

# %%
print(Y_test[0])
print(Y_test[81])
print(Y_test[82])
print(Y_test[83])
print(Y_test[84])
print(Y_test[-1])
# Out:
# [1]
# [1]
# [1]
# [0]
# [0]
# [0]

# %%
# Use numpy.unique with return_counts=True
unique_values, counts = np.unique(Y_train, return_counts=True)

# Combine unique values and their counts
value_counts = np.column_stack((unique_values, counts))

print(value_counts)
# Out:
# [[  0 335]
#  [  1 333]]

# %%
# Use numpy.unique with return_counts=True
unique_values, counts = np.unique(Y_test, return_counts=True)

# Combine unique values and their counts
value_counts = np.column_stack((unique_values, counts))

print(value_counts)
# Out:
# [[ 0 84]
#  [ 1 83]]

# %% [markdown]
# # Model Training

# %% [markdown]
# SqueezeNet Model

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, Concatenate, MaxPool2D, GlobalAvgPool2D, Activation
def squeezenet(input_shape, n_classes):

  def fire(x, fs, fe):
    s = Conv2D(fs, 1, activation='relu')(x)
    e1 = Conv2D(fe, 1, activation='relu')(s)
    e3 = Conv2D(fe, 3, padding='same', activation='relu')(s)
    output = Concatenate()([e1, e3])
    return output


  input = Input(input_shape)

  x = Conv2D(96, 7, strides=2, padding='same', activation='relu')(input)
  x = MaxPool2D(3, strides=2, padding='same')(x)

  x = fire(x, 16, 64)
  x = fire(x, 16, 64)
  x = fire(x, 32, 128)
  x = MaxPool2D(3, strides=2, padding='same')(x)

  x = fire(x, 32, 128)
  x = fire(x, 48, 192)
  x = fire(x, 48, 192)
  x = fire(x, 64, 256)
  x = MaxPool2D(3, strides=2, padding='same')(x)

  x = fire(x, 64, 256)
  x = Conv2D(n_classes, 1)(x)
  x = GlobalAvgPool2D()(x)

  output = Activation('sigmoid')(x)

  model = Model(input, output)
  return model

# %%
# Clear the TensorFlow session
tf.keras.backend.clear_session()

# %%
INPUT_SHAPE = (224, 224, 3)
N_CLASSES = 1
model = squeezenet(INPUT_SHAPE, N_CLASSES)

# %%
model_summary = model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 112, 112, 96)         14208     ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 56, 56, 96)           0         ['conv2d[0][0]']
#  D)
#
#  conv2d_1 (Conv2D)           (None, 56, 56, 16)           1552      ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 64)           1088      ['conv2d_1[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 56, 56, 64)           9280      ['conv2d_1[0][0]']
#
#  concatenate (Concatenate)   (None, 56, 56, 128)          0         ['conv2d_2[0][0]',
#                                                                      'conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 16)           2064      ['concatenate[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 64)           1088      ['conv2d_4[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 56, 56, 64)           9280      ['conv2d_4[0][0]']
#
#  concatenate_1 (Concatenate  (None, 56, 56, 128)          0         ['conv2d_5[0][0]',
#  )                                                                   'conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 56, 56, 32)           4128      ['concatenate_1[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 56, 56, 128)          4224      ['conv2d_7[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 56, 56, 128)          36992     ['conv2d_7[0][0]']
#
#  concatenate_2 (Concatenate  (None, 56, 56, 256)          0         ['conv2d_8[0][0]',
#  )                                                                   'conv2d_9[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 28, 28, 256)          0         ['concatenate_2[0][0]']
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 28, 28, 32)           8224      ['max_pooling2d_1[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 28, 28, 128)          4224      ['conv2d_10[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 28, 28, 128)          36992     ['conv2d_10[0][0]']
#
#  concatenate_3 (Concatenate  (None, 28, 28, 256)          0         ['conv2d_11[0][0]',
#  )                                                                   'conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 28, 28, 48)           12336     ['concatenate_3[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 28, 28, 192)          9408      ['conv2d_13[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 28, 28, 192)          83136     ['conv2d_13[0][0]']
#
#  concatenate_4 (Concatenate  (None, 28, 28, 384)          0         ['conv2d_14[0][0]',
#  )                                                                   'conv2d_15[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 28, 28, 48)           18480     ['concatenate_4[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 28, 28, 192)          9408      ['conv2d_16[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 28, 28, 192)          83136     ['conv2d_16[0][0]']
#
#  concatenate_5 (Concatenate  (None, 28, 28, 384)          0         ['conv2d_17[0][0]',
#  )                                                                   'conv2d_18[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 28, 28, 64)           24640     ['concatenate_5[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 28, 28, 256)          16640     ['conv2d_19[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 28, 28, 256)          147712    ['conv2d_19[0][0]']
#
#  concatenate_6 (Concatenate  (None, 28, 28, 512)          0         ['conv2d_20[0][0]',
#  )                                                                   'conv2d_21[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 14, 14, 512)          0         ['concatenate_6[0][0]']
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 14, 14, 64)           32832     ['max_pooling2d_2[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 14, 14, 256)          16640     ['conv2d_22[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 14, 14, 256)          147712    ['conv2d_22[0][0]']
#
#  concatenate_7 (Concatenate  (None, 14, 14, 512)          0         ['conv2d_23[0][0]',
#  )                                                                   'conv2d_24[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 14, 14, 1)            513       ['concatenate_7[0][0]']
#
#  global_average_pooling2d (  (None, 1)                    0         ['conv2d_25[0][0]']
#  GlobalAveragePooling2D)
#
#  activation (Activation)     (None, 1)                    0         ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 735937 (2.81 MB)
# Trainable params: 735937 (2.81 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# Generate and save images for each fire module
for i, layer in enumerate(model.layers):
    if "fire" in layer.name:
        submodel = Model(inputs=model.inputs, outputs=layer.output)
        tf.keras.utils.plot_model(submodel, to_file=f"fire_module_{i + 1}.png", show_shapes=True, show_layer_names=True, dpi=300)

# Display the saved images
for i in range(len(model.layers)):
    if "fire" in model.layers[i].name:
        img = plt.imread(f"fire_module_{i + 1}.png")
        plt.figure()
        plt.imshow(img)
        plt.axis('off')
        plt.show()

# %%
model.compile(
    optimizer='adam',
    loss= tf.keras.losses.binary_crossentropy,
    metrics=['accuracy']
)

# %%
callback = tf.keras.callbacks.ModelCheckpoint(filepath='best_model.h5',
                                              monitor='val_acc', mode='max',
                                              verbose=1)

# %%
history = model.fit(X_train,
                    Y_train,
                    validation_split=0.2,
                    batch_size = 128,
                    epochs = 50,
                    callbacks=[callback])
# Out:
# Epoch 1/50
# 5/5 [==============================] - ETA: 0s - loss: 0.6845 - accuracy: 0.6236
# Epoch 1: saving model to best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 5/5 [==============================] - 26s 1s/step - loss: 0.6845 - accuracy: 0.6236 - val_loss: 1.3363 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 5/5 [==============================] - ETA: 0s - loss: 0.6669 - accuracy: 0.6236
# Epoch 2: saving model to best_model.h5
# 5/5 [==============================] - 2s 398ms/step - loss: 0.6669 - accuracy: 0.6236 - val_loss: 0.8374 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 5/5 [==============================] - ETA: 0s - loss: 0.6672 - accuracy: 0.6236
# Epoch 3: saving model to best_model.h5
# 5/5 [==============================] - 2s 376ms/step - loss: 0.6672 - accuracy: 0.6236 - val_loss: 0.8705 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 5/5 [==============================] - ETA: 0s - loss: 0.6555 - accuracy: 0.6236
# Epoch 4: saving model to best_model.h5
# 5/5 [==============================] - 2s 324ms/step - loss: 0.6555 - accuracy: 0.6236 - val_loss: 1.0973 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 5/5 [==============================] - ETA: 0s - loss: 0.6300 - accuracy: 0.6236
# Epoch 5: saving model to best_model.h5
# 5/5 [==============================] - 2s 360ms/step - loss: 0.6300 - accuracy: 0.6236 - val_loss: 1.0607 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 5/5 [==============================] - ETA: 0s - loss: 0.5261 - accuracy: 0.7285
# Epoch 6: saving model to best_model.h5
# 5/5 [==============================] - 2s 363ms/step - loss: 0.5261 - accuracy: 0.7285 - val_loss: 0.4005 - val_accuracy: 0.8507
# Epoch 7/50
# 5/5 [==============================] - ETA: 0s - loss: 0.9338 - accuracy: 0.8820
# Epoch 7: saving model to best_model.h5
# 5/5 [==============================] - 2s 325ms/step - loss: 0.9338 - accuracy: 0.8820 - val_loss: 4.4741e-05 - val_accuracy: 1.0000
# Epoch 8/50
# 5/5 [==============================] - ETA: 0s - loss: 0.9435 - accuracy: 0.7378
# Epoch 8: saving model to best_model.h5
# 5/5 [==============================] - 2s 363ms/step - loss: 0.9435 - accuracy: 0.7378 - val_loss: 1.6441 - val_accuracy: 0.0896
# Epoch 9/50
# 5/5 [==============================] - ETA: 0s - loss: 0.2701 - accuracy: 0.8633
# Epoch 9: saving model to best_model.h5
# 5/5 [==============================] - 2s 325ms/step - loss: 0.2701 - accuracy: 0.8633 - val_loss: 0.0932 - val_accuracy: 1.0000
# Epoch 10/50
# 5/5 [==============================] - ETA: 0s - loss: 0.2175 - accuracy: 0.9401
# Epoch 10: saving model to best_model.h5
# 5/5 [==============================] - 2s 385ms/step - loss: 0.2175 - accuracy: 0.9401 - val_loss: 1.1077 - val_accuracy: 0.0672
# Epoch 11/50
# 5/5 [==============================] - ETA: 0s - loss: 0.2944 - accuracy: 0.8127
# Epoch 11: saving model to best_model.h5
# 5/5 [==============================] - 2s 368ms/step - loss: 0.2944 - accuracy: 0.8127 - val_loss: 0.5973 - val_accuracy: 0.7164
# Epoch 12/50
# 5/5 [==============================] - ETA: 0s - loss: 0.2157 - accuracy: 0.9850
# Epoch 12: saving model to best_model.h5
# 5/5 [==============================] - 2s 369ms/step - loss: 0.2157 - accuracy: 0.9850 - val_loss: 0.2501 - val_accuracy: 1.0000
# Epoch 13/50
# 5/5 [==============================] - ETA: 0s - loss: 0.1640 - accuracy: 0.9850
# Epoch 13: saving model to best_model.h5
# 5/5 [==============================] - 2s 329ms/step - loss: 0.1640 - accuracy: 0.9850 - val_loss: 0.5372 - val_accuracy: 0.7537
# Epoch 14/50
# 5/5 [==============================] - ETA: 0s - loss: 0.1065 - accuracy: 0.9944
# Epoch 14: saving model to best_model.h5
# 5/5 [==============================] - 2s 363ms/step - loss: 0.1065 - accuracy: 0.9944 - val_loss: 0.2676 - val_accuracy: 0.9403
# Epoch 15/50
# 5/5 [==============================] - ETA: 0s - loss: 0.0567 - accuracy: 1.0000
# Epoch 15: saving model to best_model.h5
# 5/5 [==============================] - 2s 328ms/step - loss: 0.0567 - accuracy: 1.0000 - val_loss: 0.1912 - val_accuracy: 0.9478
# Epoch 16/50
# 5/5 [==============================] - ETA: 0s - loss: 0.0321 - accuracy: 1.0000
# Epoch 16: saving model to best_model.h5
# 5/5 [==============================] - 2s 326ms/step - loss: 0.0321 - accuracy: 1.0000 - val_loss: 0.2535 - val_accuracy: 0.9179
# Epoch 17/50
# 5/5 [==============================] - ETA: 0s - loss: 0.0179 - accuracy: 1.0000
# Epoch 17: saving model to best_model.h5
# 5/5 [==============================] - 2s 328ms/step - loss: 0.0179 - accuracy: 1.0000 - val_loss: 0.0791 - val_accuracy: 0.9851
# Epoch 18/50
# 5/5 [==============================] - ETA: 0s - loss: 0.0107 - accuracy: 1.0000
# Epoch 18: saving model to best_model.h5
# 5/5 [==============================] - 2s 339ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.2725 - val_accuracy: 0.8881
# Epoch 19/50
# 5/5 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.9981
# Epoch 19: saving model to best_model.h5
# 5/5 [==============================] - 2s 397ms/step - loss: 0.0085 - accuracy: 0.9981 - val_loss: 0.0963 - val_accuracy: 0.9552
# Epoch 20/50
# 5/5 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 20: saving model to best_model.h5
# 5/5 [==============================] - 2s 385ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0531 - val_accuracy: 0.9851
# Epoch 21/50
# 5/5 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 1.0000
# Epoch 21: saving model to best_model.h5
# 5/5 [==============================] - 2s 365ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1318 - val_accuracy: 0.9403
# Epoch 22/50
# 5/5 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 1.0000
# Epoch 22: saving model to best_model.h5
# 5/5 [==============================] - 2s 335ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0840 - val_accuracy: 0.9627
# Epoch 23/50
# 5/5 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 23: saving model to best_model.h5
# 5/5 [==============================] - 2s 364ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0519 - val_accuracy: 0.9851
# Epoch 24/50
# 5/5 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 24: saving model to best_model.h5
# 5/5 [==============================] - 2s 366ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0363 - val_accuracy: 0.9851
# Epoch 25/50
# 5/5 [==============================] - ETA: 0s - loss: 9.6830e-04 - accuracy: 1.0000
# Epoch 25: saving model to best_model.h5
# 5/5 [==============================] - 2s 363ms/step - loss: 9.6830e-04 - accuracy: 1.0000 - val_loss: 0.0776 - val_accuracy: 0.9701
# Epoch 26/50
# 5/5 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 26: saving model to best_model.h5
# 5/5 [==============================] - 2s 339ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0499 - val_accuracy: 0.9851
# Epoch 27/50
# 5/5 [==============================] - ETA: 0s - loss: 6.3135e-04 - accuracy: 1.0000
# Epoch 27: saving model to best_model.h5
# 5/5 [==============================] - 2s 365ms/step - loss: 6.3135e-04 - accuracy: 1.0000 - val_loss: 0.0257 - val_accuracy: 1.0000
# Epoch 28/50
# 5/5 [==============================] - ETA: 0s - loss: 5.7403e-04 - accuracy: 1.0000
# Epoch 28: saving model to best_model.h5
# 5/5 [==============================] - 2s 359ms/step - loss: 5.7403e-04 - accuracy: 1.0000 - val_loss: 0.0268 - val_accuracy: 1.0000
# Epoch 29/50
# 5/5 [==============================] - ETA: 0s - loss: 3.7651e-04 - accuracy: 1.0000
# Epoch 29: saving model to best_model.h5
# 5/5 [==============================] - 2s 375ms/step - loss: 3.7651e-04 - accuracy: 1.0000 - val_loss: 0.0383 - val_accuracy: 0.9851
# Epoch 30/50
# 5/5 [==============================] - ETA: 0s - loss: 3.6950e-04 - accuracy: 1.0000
# Epoch 30: saving model to best_model.h5
# 5/5 [==============================] - 2s 329ms/step - loss: 3.6950e-04 - accuracy: 1.0000 - val_loss: 0.0328 - val_accuracy: 0.9851
# Epoch 31/50
# 5/5 [==============================] - ETA: 0s - loss: 2.9437e-04 - accuracy: 1.0000
# Epoch 31: saving model to best_model.h5
# 5/5 [==============================] - 2s 364ms/step - loss: 2.9437e-04 - accuracy: 1.0000 - val_loss: 0.0160 - val_accuracy: 1.0000
# Epoch 32/50
# 5/5 [==============================] - ETA: 0s - loss: 2.8090e-04 - accuracy: 1.0000
# Epoch 32: saving model to best_model.h5
# 5/5 [==============================] - 2s 365ms/step - loss: 2.8090e-04 - accuracy: 1.0000 - val_loss: 0.0141 - val_accuracy: 1.0000
# Epoch 33/50
# 5/5 [==============================] - ETA: 0s - loss: 2.2098e-04 - accuracy: 1.0000
# Epoch 33: saving model to best_model.h5
# 5/5 [==============================] - 2s 335ms/step - loss: 2.2098e-04 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 1.0000
# Epoch 34/50
# 5/5 [==============================] - ETA: 0s - loss: 2.0909e-04 - accuracy: 1.0000
# Epoch 34: saving model to best_model.h5
# 5/5 [==============================] - 2s 330ms/step - loss: 2.0909e-04 - accuracy: 1.0000 - val_loss: 0.0192 - val_accuracy: 1.0000
# Epoch 35/50
# 5/5 [==============================] - ETA: 0s - loss: 1.8007e-04 - accuracy: 1.0000
# Epoch 35: saving model to best_model.h5
# 5/5 [==============================] - 2s 374ms/step - loss: 1.8007e-04 - accuracy: 1.0000 - val_loss: 0.0140 - val_accuracy: 1.0000
# Epoch 36/50
# 5/5 [==============================] - ETA: 0s - loss: 1.8197e-04 - accuracy: 1.0000
# Epoch 36: saving model to best_model.h5
# 5/5 [==============================] - 2s 404ms/step - loss: 1.8197e-04 - accuracy: 1.0000 - val_loss: 0.0137 - val_accuracy: 1.0000
# Epoch 37/50
# 5/5 [==============================] - ETA: 0s - loss: 1.6698e-04 - accuracy: 1.0000
# Epoch 37: saving model to best_model.h5
# 5/5 [==============================] - 2s 378ms/step - loss: 1.6698e-04 - accuracy: 1.0000 - val_loss: 0.0184 - val_accuracy: 1.0000
# Epoch 38/50
# 5/5 [==============================] - ETA: 0s - loss: 1.5993e-04 - accuracy: 1.0000
# Epoch 38: saving model to best_model.h5
# 5/5 [==============================] - 2s 371ms/step - loss: 1.5993e-04 - accuracy: 1.0000 - val_loss: 0.0155 - val_accuracy: 1.0000
# Epoch 39/50
# 5/5 [==============================] - ETA: 0s - loss: 1.4739e-04 - accuracy: 1.0000
# Epoch 39: saving model to best_model.h5
# 5/5 [==============================] - 2s 366ms/step - loss: 1.4739e-04 - accuracy: 1.0000 - val_loss: 0.0145 - val_accuracy: 1.0000
# Epoch 40/50
# 5/5 [==============================] - ETA: 0s - loss: 1.4071e-04 - accuracy: 1.0000
# Epoch 40: saving model to best_model.h5
# 5/5 [==============================] - 2s 336ms/step - loss: 1.4071e-04 - accuracy: 1.0000 - val_loss: 0.0150 - val_accuracy: 1.0000
# Epoch 41/50
# 5/5 [==============================] - ETA: 0s - loss: 1.3459e-04 - accuracy: 1.0000
# Epoch 41: saving model to best_model.h5
# 5/5 [==============================] - 2s 336ms/step - loss: 1.3459e-04 - accuracy: 1.0000 - val_loss: 0.0151 - val_accuracy: 1.0000
# Epoch 42/50
# 5/5 [==============================] - ETA: 0s - loss: 1.2681e-04 - accuracy: 1.0000
# Epoch 42: saving model to best_model.h5
# 5/5 [==============================] - 2s 367ms/step - loss: 1.2681e-04 - accuracy: 1.0000 - val_loss: 0.0135 - val_accuracy: 1.0000
# Epoch 43/50
# 5/5 [==============================] - ETA: 0s - loss: 1.2091e-04 - accuracy: 1.0000
# Epoch 43: saving model to best_model.h5
# 5/5 [==============================] - 2s 388ms/step - loss: 1.2091e-04 - accuracy: 1.0000 - val_loss: 0.0124 - val_accuracy: 1.0000
# Epoch 44/50
# 5/5 [==============================] - ETA: 0s - loss: 1.1278e-04 - accuracy: 1.0000
# Epoch 44: saving model to best_model.h5
# 5/5 [==============================] - 2s 402ms/step - loss: 1.1278e-04 - accuracy: 1.0000 - val_loss: 0.0138 - val_accuracy: 1.0000
# Epoch 45/50
# 5/5 [==============================] - ETA: 0s - loss: 1.0659e-04 - accuracy: 1.0000
# Epoch 45: saving model to best_model.h5
# 5/5 [==============================] - 2s 352ms/step - loss: 1.0659e-04 - accuracy: 1.0000 - val_loss: 0.0144 - val_accuracy: 1.0000
# Epoch 46/50
# 5/5 [==============================] - ETA: 0s - loss: 1.0285e-04 - accuracy: 1.0000
# Epoch 46: saving model to best_model.h5
# 5/5 [==============================] - 2s 335ms/step - loss: 1.0285e-04 - accuracy: 1.0000 - val_loss: 0.0124 - val_accuracy: 1.0000
# Epoch 47/50
# 5/5 [==============================] - ETA: 0s - loss: 9.4349e-05 - accuracy: 1.0000
# Epoch 47: saving model to best_model.h5
# 5/5 [==============================] - 2s 370ms/step - loss: 9.4349e-05 - accuracy: 1.0000 - val_loss: 0.0132 - val_accuracy: 1.0000
# Epoch 48/50
# 5/5 [==============================] - ETA: 0s - loss: 8.8973e-05 - accuracy: 1.0000
# Epoch 48: saving model to best_model.h5
# 5/5 [==============================] - 2s 340ms/step - loss: 8.8973e-05 - accuracy: 1.0000 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 49/50
# 5/5 [==============================] - ETA: 0s - loss: 8.2469e-05 - accuracy: 1.0000
# Epoch 49: saving model to best_model.h5
# 5/5 [==============================] - 2s 334ms/step - loss: 8.2469e-05 - accuracy: 1.0000 - val_loss: 0.0108 - val_accuracy: 1.0000
# Epoch 50/50
# 5/5 [==============================] - ETA: 0s - loss: 7.7193e-05 - accuracy: 1.0000
# Epoch 50: saving model to best_model.h5
# 5/5 [==============================] - 2s 334ms/step - loss: 7.7193e-05 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 1.0000

# %% [markdown]
# # Plot Model Progression

# %% [markdown]
# Accuracy (training vs validation dataset)

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# Loss (training vs validation dataset)

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# Combined Loss & Accuracy

# %%
# Plot the training and validation accuracy and loss over epochs
plt.figure(figsize=(10, 6), dpi=150)

# Plot accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy', linewidth=2)
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)

# Plot loss
plt.plot(history.history['loss'], label='Train Loss', linewidth=2)
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)

plt.xlabel('Epoch', fontweight='bold')
plt.ylabel('Value', fontweight='bold')
plt.title('Training and Validation Metrics', fontweight='bold')
plt.legend()
plt.grid(True)

# Save the figure
#plt.savefig('accuracy_loss_curve.png', dpi=300)
plt.show()

# %% [markdown]
# Load best model weights

# %%
model.load_weights('best_model.h5')

# %% [markdown]
# Print model weights

# %%
'''# Load your pre-trained model (replace 'model.h5' with your model's filename)
best_model = tf.keras.models.load_model('best_model.h5')
# Define the path where you want to save the model
model_save_path = '/content/drive/My Drive/Colab Notebooks/Skin Cancer Classification/'

# Save the best model to Google Drive
best_model.save(model_save_path + 'best_model_squeezenet.h5')

# Get the list of all layers in the model
all_layers = best_model.layers

# Loop through the layers and print their weights if they have any
for layer in all_layers:
    if layer.weights:
        print(f"Layer: {layer.name}")
        for weight in layer.weights:
            print(f"  {weight.name}:")
            print(weight.numpy())'''
# Out:
# '# Load your pre-trained model (replace \'model.h5\' with your model\'s filename)\nbest_model = tf.keras.models.load_model(\'best_model.h5\')\n# Define the path where you want to save the model\nmodel_save_path = \'/content/drive/My Drive/Colab Notebooks/Skin Cancer Classification/\'\n\n# Save the best model to Google Drive\nbest_model.save(model_save_path + \'best_model_squeezenet.h5\')\n\n# Get the list of all layers in the model\nall_layers = best_model.layers\n\n# Loop through the layers and print their weights if they have any\nfor layer in all_layers:\n    if layer.weights:\n        print(f"Layer: {layer.name}")\n        for weight in layer.weights:\n            print(f"  {weight.name}:")\n            print(weight.numpy())'

# %% [markdown]
# # Model Testing

# %%
#loss, acc = model.evaluate(X_test, Y_test, verbose=2)

# %%
import sklearn.metrics as metrics

y_pred_ohe = model.predict(X_test)
#y_pred_labels = np.argmax(y_pred_ohe, axis=1)
# Out:
# 6/6 [==============================] - 2s 183ms/step

# %%
#print(y_pred_ohe)

# %%
threshold = 0.6
y_pred_labels = (y_pred_ohe >= threshold).astype(int)

# %%
# Save predictions as a NumPy array
np.save('squeezenet_predictions.npy', y_pred_labels)

# %%
#print(y_pred_labels)

# %%
confusion_matrix = metrics.confusion_matrix(y_true=Y_test, y_pred=y_pred_labels)
print(confusion_matrix)
# Out:
# [[84  0]
#  [ 0 83]]

# %%
from sklearn.metrics import classification_report
class_labels = ['benign', 'malignant']
report = classification_report(Y_test, y_pred_labels, target_names = class_labels)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#       benign       1.00      1.00      1.00        84
#    malignant       1.00      1.00      1.00        83
#
#     accuracy                           1.00       167
#    macro avg       1.00      1.00      1.00       167
# weighted avg       1.00      1.00      1.00       167

# %%
import seaborn as sns

cm = confusion_matrix
plt.figure(figsize=(8,8))
sns.heatmap(cm, fmt='.0f', cmap="crest", annot=True, linewidths=0.2)
plt.title('Confusion matrix')
plt.xlabel('Predicted value')
plt.ylabel('Truth value')
plt.show()
#print(confusion_matrix(Y_test, y_pred_labels))

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc


# Calculate accuracy, precision, recall, and F1-score
accuracy = accuracy_score(Y_test, y_pred_labels)
precision = precision_score(Y_test, y_pred_labels)
recall = recall_score(Y_test, y_pred_labels)
f1 = f1_score(Y_test, y_pred_labels)

print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-score: {f1:.2f}")
# Out:
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# F1-score: 1.00

# %%
# Plot ROC curve
fpr, tpr, _ = roc_curve(Y_test, y_pred_labels)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(10, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
